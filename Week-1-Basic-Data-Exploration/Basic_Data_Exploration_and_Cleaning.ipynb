# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\harsh\Downloads\archive\Customer shopping.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                  No         PayPal    Store Pickup
# ...

# %%
df.shape # y 3900 rows ha aur 19 column
# Out:
# (3900, 19)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df[['Customer ID', 'Gender', 'Category']].head()
# Out:
#    Customer ID Gender  Category
# 0            1   Male  Clothing
# 1            2   Male  Clothing
# 2            3   Male  Clothing
# 3            4   Male  Footwear
# 4            5   Male  Clothing

# %%
female_customers = df[df['Gender'] == 'Female']
female_customers.head()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2652         2653   23  Female         Shorts     Clothing
# 2653         2654   67  Female         Blouse     Clothing
# 2654         2655   23  Female           Coat    Outerwear
# 2655         2656   26  Female     Sunglasses  Accessories
# 2656         2657   52  Female         Shorts     Clothing
#
#       Purchase Amount (USD)   Location Size     Color  Season  Review Rating  \
# 2652                     20   Maryland    L      Cyan  Summer            3.3
# 2653                     36  Wisconsin    L  Lavender    Fall            4.8
# 2654                     70      Idaho    S      Pink    Fall            4.1
# 2655                     83    Wyoming    M      Gray  Summer            3.4
# 2656                     76    Indiana    L    Yellow  Winter            3.6
#
#      Subscription Status Payment Method   Shipping Type Discount Applied  \
# ...

# %%
high_purchase = df[df['Purchase Amount (USD)'] > 50]
high_purchase.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 6            7   63   Male          Shirt  Clothing                     85
#
#         Location Size   Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L    Gray  Winter            3.1                 Yes
# 1          Maine    L  Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S  Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M  Maroon  Spring            3.5                 Yes
# 6        Montana    M    Gray    Fall            3.2                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates() # since there is no duplicates in the dataset hence it is not returning any output

# %%
df['Quantity'] = 1

# %%
df['Total_Amount'] = df['Purchase Amount (USD)'] * df['Quantity']

# %%
df[['Purchase Amount (USD)', 'Quantity', 'Total_Amount']].head()
# Out:
#    Purchase Amount (USD)  Quantity  Total_Amount
# 0                     53         1            53
# 1                     64         1            64
# 2                     73         1            73
# 3                     90         1            90
# 4                     49         1            49

# %%
df.to_csv("cleaned_shopping_dataset.csv", index=False)

# %% [markdown]
# # Summary
#
# # 1. Loaded the shopping dataset using Pandas.
# # 2. Explored the dataset using head(), tail(), shape, columns, and data types.
# # 3. Checked for missing values and found no missing data.
# # 4. Selected specific columns and filtered rows based on conditions.
# # 5. Checked duplicate records but none found ,so removing duplicate record output has give no output.
# # 6. Created a derived column named Total_Amount.
# # 7. Saved the cleaned dataset as cleaned_shopping_dataset.csv.
#
# # The dataset was successfully cleaned and prepared for further analysis.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\harsh
